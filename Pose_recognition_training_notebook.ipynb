# %% [markdown]
# # 0. Install and Import Dependencies

# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\33642\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import mediapipe as mp # Import mediapipe
import cv2 # Import opencv

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %% [markdown]
# # 1. Detections

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 2. Collecting landmarks coordinates and Exporting to CSV

# %%
import csv
import os
import numpy as np

# %%
num_coords = len(results.pose_landmarks.landmark)
num_coords
# Out:
# 33

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
# ...

# %%
#exporting columns in csv

with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "Arms_up"

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        

        # Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
        
            row = pose_row
            
            # Append class name 
            row.insert(0, class_name)
            
            # Export to CSV
            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row) 
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 3. Training Custom Model Using Scikit Learn

# %% [markdown]
# ## 3.1 Processing data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('coords.csv')

# %%
df.head()
# Out:
#         class        x1        y1        z1        v1        x2        y2  \
# 0  No_stretch  0.536299  0.525902 -0.527516  0.999935  0.545537  0.501659
# 1  No_stretch  0.535954  0.523124 -0.531684  0.999914  0.545899  0.499712
# 2  No_stretch  0.535486  0.522412 -0.519136  0.999889  0.546118  0.499449
# 3  No_stretch  0.535004  0.522096 -0.517463  0.999858  0.546152  0.499398
# 4  No_stretch  0.534146  0.521925 -0.500095  0.999863  0.546101  0.499376
#
#          z2        v2        x3  ...       z31       v31       x32       y32  \
# 0 -0.493563  0.999844  0.551871  ...  0.586992  0.020630  0.564716  1.419803
# 1 -0.498015  0.999783  0.552474  ...  0.159208  0.027232  0.572788  1.447774
# 2 -0.485002  0.999716  0.553044  ...  0.161970  0.032399  0.574628  1.463767
# 3 -0.483712  0.999629  0.553234  ...  0.181600  0.035676  0.578600  1.478052
# 4 -0.465806  0.999643  0.553230  ...  0.065433  0.051959  0.578207  1.466588
#
# ...

# %%
df.tail()
# Out:
#        class        x1        y1        z1        v1        x2        y2  \
# 796  Arms_up  0.493034  0.494379 -0.524621  0.999467  0.506515  0.458834
# 797  Arms_up  0.493437  0.492829 -0.481354  0.999455  0.505768  0.459102
# 798  Arms_up  0.491774  0.492914 -0.494064  0.999377  0.504007  0.459295
# 799  Arms_up  0.489717  0.493309 -0.490349  0.999382  0.502315  0.459486
# 800  Arms_up  0.491184  0.492901 -0.504013  0.999351  0.503646  0.459500
#
#            z2        v2        x3  ...       z31       v31       x32  \
# 796 -0.477316  0.999423  0.514658  ...  0.004266  0.143543  0.540594
# 797 -0.432306  0.999404  0.513521  ... -0.015116  0.147382  0.517464
# 798 -0.445046  0.999322  0.511868  ... -0.022716  0.144084  0.522168
# 799 -0.444955  0.999324  0.510263  ... -0.032031  0.142995  0.532074
# 800 -0.459322  0.999289  0.511504  ... -0.025895  0.141979  0.533322
#
#           y32       z32       v32       x33       y33       z33       v33
# ...

# %%
df[df['class']=='No_stretch']
# Out:
#           class        x1        y1        z1        v1        x2        y2  \
# 0    No_stretch  0.536299  0.525902 -0.527516  0.999935  0.545537  0.501659
# 1    No_stretch  0.535954  0.523124 -0.531684  0.999914  0.545899  0.499712
# 2    No_stretch  0.535486  0.522412 -0.519136  0.999889  0.546118  0.499449
# 3    No_stretch  0.535004  0.522096 -0.517463  0.999858  0.546152  0.499398
# 4    No_stretch  0.534146  0.521925 -0.500095  0.999863  0.546101  0.499376
# ..          ...       ...       ...       ...       ...       ...       ...
# 241  No_stretch  0.539013  0.492551 -0.322553  0.999915  0.550501  0.458750
# 242  No_stretch  0.538673  0.492500 -0.323797  0.999917  0.550362  0.458815
# 243  No_stretch  0.538564  0.492618 -0.324445  0.999920  0.550292  0.459004
# 244  No_stretch  0.538161  0.492620 -0.324789  0.999922  0.549995  0.459106
# 245  No_stretch  0.537877  0.492601 -0.325432  0.999927  0.549739  0.459138
#
# ...

# %%
X = df.drop('class', axis=1) # features
y = df['class'] # target value

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 192    No_stretch
# 65     No_stretch
# 606       Arms_up
# 60     No_stretch
# 537       Arms_up
#           ...
# 467     Wide_arms
# 278     Wide_arms
# 93     No_stretch
# 221    No_stretch
# 543       Arms_up
# Name: class, Length: 241, dtype: object

# %% [markdown]
# ## 3.2 Training a Machine Learning Classification Model

# %%
# Building ML pipeline
from sklearn.pipeline import make_pipeline 
# Standardizes the data
from sklearn.preprocessing import StandardScaler 

# Classifiction algorithms
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# We test all of them, and pick the best one

# %%
# Defining our pipelines / machine learning models. Creating keys.
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
# Looping through the pipelines
for algo, pipeline in pipelines.items():
    # Training
    model = pipeline.fit(X_train, y_train)
    # Storing the model
    fit_models[algo] = model

# %%
X_train
# Out:
#            x1        y1        z1        v1        x2        y2        z2  \
# 33   0.540825  0.492072 -0.286207  0.999768  0.551353  0.464855 -0.251444
# 194  0.541914  0.486702 -0.389552  0.999975  0.552072  0.458510 -0.354016
# 598  0.532249  0.563170 -0.509781  0.999675  0.541483  0.525435 -0.469225
# 620  0.545208  0.489330 -0.614433  0.999753  0.557025  0.453414 -0.568020
# 767  0.533654  0.537749 -0.457134  0.998553  0.537849  0.516362 -0.405250
# ..        ...       ...       ...       ...       ...       ...       ...
# 372  0.528694  0.510708 -0.600819  0.999970  0.537082  0.486311 -0.566546
# 204  0.532001  0.484692 -0.388186  0.999944  0.544841  0.456136 -0.361221
# 53   0.541691  0.483098 -0.327938  0.999946  0.553888  0.457423 -0.298788
# 294  0.523772  0.512568 -0.697246  0.999887  0.534648  0.487179 -0.664608
# 723  0.532241  0.494518 -0.647926  0.999601  0.541828  0.461053 -0.604315
#
#            v2        x3        y3  ...       z31       v31       x32  \
# ...

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['No_stretch', 'No_stretch', 'Arms_up', 'No_stretch', 'Arms_up',
#        'Arms_up', 'No_stretch', 'No_stretch', 'No_stretch', 'Arms_up',
#        'Arms_up', 'Wide_arms', 'No_stretch', 'Arms_up', 'Arms_up',
#        'No_stretch', 'Wide_arms', 'Wide_arms', 'No_stretch', 'Arms_up',
#        'No_stretch', 'Arms_up', 'Arms_up', 'Wide_arms', 'Wide_arms',
#        'No_stretch', 'Arms_up', 'Wide_arms', 'Wide_arms', 'Wide_arms',
#        'Arms_up', 'Wide_arms', 'Wide_arms', 'Arms_up', 'No_stretch',
#        'Arms_up', 'No_stretch', 'No_stretch', 'Wide_arms', 'Wide_arms',
#        'No_stretch', 'No_stretch', 'Arms_up', 'No_stretch', 'Wide_arms',
#        'Arms_up', 'Arms_up', 'Arms_up', 'No_stretch', 'No_stretch',
#        'Wide_arms', 'Wide_arms', 'Wide_arms', 'Arms_up', 'Wide_arms',
#        'Wide_arms', 'No_stretch', 'No_stretch', 'Arms_up', 'Arms_up',
#        'Arms_up', 'Wide_arms', 'No_stretch', 'No_stretch', 'Wide_arms',
# ...

# %% [markdown]
# ## 3.3 Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics, for evaluating the model
#We could also use precision, sensitivity, specificity or F1 score for example
import pickle # Used to save the model

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 1.0

# %% [markdown]
# Result is great! Maybe try other evaluation techniques afterwards

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['No_stretch', 'No_stretch', 'Arms_up', 'No_stretch', 'Arms_up',
#        'Arms_up', 'No_stretch', 'No_stretch', 'No_stretch', 'Arms_up',
#        'Arms_up', 'Wide_arms', 'No_stretch', 'Arms_up', 'Arms_up',
#        'No_stretch', 'Wide_arms', 'Wide_arms', 'No_stretch', 'Arms_up',
#        'No_stretch', 'Arms_up', 'Arms_up', 'Wide_arms', 'Wide_arms',
#        'No_stretch', 'Arms_up', 'Wide_arms', 'Wide_arms', 'Wide_arms',
#        'Arms_up', 'Wide_arms', 'Wide_arms', 'Arms_up', 'No_stretch',
#        'Arms_up', 'No_stretch', 'No_stretch', 'Wide_arms', 'Wide_arms',
#        'No_stretch', 'No_stretch', 'Arms_up', 'No_stretch', 'Wide_arms',
#        'Arms_up', 'Arms_up', 'Arms_up', 'No_stretch', 'No_stretch',
#        'Wide_arms', 'Wide_arms', 'Wide_arms', 'Arms_up', 'Wide_arms',
#        'Wide_arms', 'No_stretch', 'No_stretch', 'Arms_up', 'Arms_up',
#        'Arms_up', 'Wide_arms', 'No_stretch', 'No_stretch', 'Wide_arms',
# ...

# %%
y_test
# Out:
# 192    No_stretch
# 65     No_stretch
# 606       Arms_up
# 60     No_stretch
# 537       Arms_up
#           ...
# 467     Wide_arms
# 278     Wide_arms
# 93     No_stretch
# 221    No_stretch
# 543       Arms_up
# Name: class, Length: 241, dtype: object

# %%
# Exporting our model, here we chose random forest model, can try other ones
with open('stretches.pkl', 'wb') as f: # writing
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # 4. Make Detections with Model

# %%
# Reloading our model
with open('stretches.pkl', 'rb') as f: #reading
    model = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13392/1555288240.py in <module>
#       1 # Reloading our model
# ----> 2 with open('stretches.pkl', 'rb') as f: #reading
#       3     model = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stretches.pkl'

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        

        #  Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            row = pose_row
            

            # Make Detections
            X = pd.DataFrame([row])
            stretch_class = model.predict(X)[0]
            stretch_prob = model.predict_proba(X)[0]
            print(stretch_class, stretch_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(stretch_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, stretch_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, stretch_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(stretch_prob[np.argmax(stretch_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\33642\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\33642\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# No_stretch [0.04 0.8  0.16]
# C:\Users\33642\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\33642\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...

# %%
tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))

# %% [markdown]
# Results are good, maybe give more variability in the data for training : varying distance, orientation... but the random forest classifier already gives a great performance.
